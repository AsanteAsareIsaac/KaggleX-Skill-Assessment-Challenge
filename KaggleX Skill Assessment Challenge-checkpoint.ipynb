# %%
# !pip install category-encoders
# Out:
# Collecting category-encoders
#   Obtaining dependency information for category-encoders from https://files.pythonhosted.org/packages/7f/e5/79a62e5c9c9ddbfa9ff5222240d408c1eeea4e38741a0dc8343edc7ef1ec/category_encoders-2.6.3-py2.py3-none-any.whl.metadata
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (1.24.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (1.3.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (1.11.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hp\anaconda3\lib\site-packages (from category-encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.0.5->category-encoders) (2023.3)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category-encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category-encoders) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels>=0.9.0->category-encoders) (23.1)
# Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/81.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/81.9 kB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 30.7/81.9 kB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    -------------------- ------------------- 41.0/81.9 kB 279.3 kB/s eta 0:00:01
#    ------------------------------ --------- 61.4/81.9 kB 81.9 kB/s eta 0:00:01
#    ------------------------------ --------- 61.4/81.9 kB 81.9 kB/s eta 0:00:01
#    ---------------------------------------- 81.9/81.9 kB 95.5 kB/s eta 0:00:00
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.6.3

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from category_encoders import TargetEncoder
import category_encoders as ce
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# 2                     6-Speed A/T  Purple   Beige  None reported         Yes
# 3  Transmission w/Dual Shift Mode    Gray   Brown  None reported         Yes
# 4                             A/T   White   Black  None reported         Yes
#
#    price
# 0  11000
# 1   8250
# 2  15000
# 3  63500
# 4   7850

# %%
df_train.columns
# Out:
# Index(['id', 'brand', 'model', 'model_year', 'milage', 'fuel_type', 'engine',
#        'transmission', 'ext_col', 'int_col', 'accident', 'clean_title',
#        'price'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# id               int64
# brand           object
# model           object
# model_year       int64
# milage           int64
# fuel_type       object
# engine          object
# transmission    object
# ext_col         object
# int_col         object
# accident        object
# clean_title     object
# price            int64
# dtype: object

# %%
train_id = df_train['id']
test_id = df_test['id']

# %%
df_train.drop(columns=['id'], inplace = True)
df_test.drop(columns=['id'], inplace = True)

# %%
df_test.shape
# Out:
# (36183, 11)

# %%
#Now let's have a look at how many labels each variable has
for col in df_train.columns:
    print(col, ': ', len(df_train[col].unique()), ' labels')
# Out:
# brand :  53  labels
# model :  1827  labels
# model_year :  34  labels
# milage :  3212  labels
# fuel_type :  7  labels
# engine :  1061  labels
# transmission :  46  labels
# ext_col :  260  labels
# int_col :  124  labels
# accident :  2  labels
# clean_title :  1  labels
# price :  1481  labels

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_train['model_year'], df_train['milage'], color='blue', s=100)
plt.title('Milage vs. Model Year')
plt.xlabel('Model Year')
plt.ylabel('Milage')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_train['model_year'], df_train['price'], color='green', s=100)
plt.title('Price vs. Model Year')
plt.xlabel('Model Year')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_train['milage'], df_train['price'], color='green', s=100)
plt.title('Price vs. Milage')
plt.xlabel('Milager')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
df_train[df_train['milage']>350000]
# Out:
#                brand                             model  model_year  milage  \
# 8674           Mazda       MX-5 Miata RF Grand Touring        2016  405000
# 15749  Mercedes-Benz                     Sprinter 2500        2011  399000
# 15822  Mercedes-Benz                     Sprinter 2500        2004  399000
# 20025           Ford  F-350 Lariat Super Duty Crew Cab        2009  399000
# 39640      Chevrolet                     Corvette Base        2004  405000
# 40126            Kia                         Optima LX        2018  405000
# 42738  Mercedes-Benz                     Sprinter 2500        2016  399000
# 46001          Honda                      Accord Sport        2013  405000
#
#       fuel_type                                        engine  \
# 8674   Gasoline  155.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# 15749    Diesel   188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 15822    Diesel   188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 20025    Diesel    350.0HP 6.4L 8 Cylinder Engine Diesel Fuel
# 39640  Gasoline  345.0HP 5.7L 8 Cylinder Engine Gasoline Fuel
# 40126  Gasoline  185.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
# 42738    Diesel   188.0HP 3.0L V6 Cylinder Engine Diesel Fuel
# 46001  Gasoline  185.0HP 2.4L 4 Cylinder Engine Gasoline Fuel
#
#            transmission ext_col int_col  \
# 8674        6-Speed M/T   Brown   Black
# 15749       5-Speed A/T   White       –
# 15822       5-Speed A/T   White    Gray
# 20025       5-Speed A/T   White   Beige
# 39640       6-Speed M/T  Orange   Black
# 40126               A/T   White   Beige
# 42738               A/T   White       –
# 46001  CVT Transmission   Black   Black
#
#                                      accident clean_title  price
# 8674                            None reported         Yes  16750
# 15749  At least 1 accident or damage reported         Yes  13000
# 15822                           None reported         Yes   9950
# 20025                           None reported         Yes  69995
# 39640  At least 1 accident or damage reported         Yes  15000
# 40126  At least 1 accident or damage reported         Yes  26497
# 42738  At least 1 accident or damage reported         Yes  16500
# 46001                           None reported         Yes   4399

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_train['fuel_type'], df_train['price'], color='green', s=100)
plt.title('Price vs. fuel type')
plt.xlabel('fuel type')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
df_train[df_train['fuel_type']=='not supported']
# Out:
#         brand            model  model_year  milage      fuel_type  \
# 1069   Toyota       Mirai Base        2016   40000  not supported
# 9621   Toyota    Mirai Limited        2023   29553  not supported
# 11441  Toyota    Mirai Limited        2018   40000  not supported
# 21771  Nissan  Armada Platinum        2017   92000  not supported
#
#                                              engine  \
# 1069           151.0HP Electric Motor Hydrogen Fuel
# 9621           182.0HP Electric Motor Hydrogen Fuel
# 11441          182.0HP Electric Motor Hydrogen Fuel
# 21771  390.0HP 5.6L 8 Cylinder Engine Gasoline Fuel
#
#                          transmission ext_col int_col       accident  \
# 1069                              A/T  Silver   Black  None reported
# 9621                              A/T  Silver    Gray  None reported
# 11441                             A/T  Silver    Gray  None reported
# 21771  Transmission w/Dual Shift Mode    Gray   Black  None reported
#
#       clean_title  price
# 1069          Yes  14000
# 9621          Yes   9995
# 11441         Yes   7500
# 21771         Yes  20900

# %%
df_train.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df_train.dtypes
# Out:
# brand           object
# model           object
# model_year       int64
# milage           int64
# fuel_type       object
# engine          object
# transmission    object
# ext_col         object
# int_col         object
# accident        object
# clean_title     object
# price            int64
# dtype: object

# %%
label_encoder = LabelEncoder()
df_train['brand'] = label_encoder.fit_transform(df_train['brand'])
df_train['fuel_type'] = label_encoder.fit_transform(df_train['fuel_type'])
df_train['ext_col'] = label_encoder.fit_transform(df_train['ext_col'])
df_train['int_col'] = label_encoder.fit_transform(df_train['int_col'])
df_train['model'] = label_encoder.fit_transform(df_train['model'])

# %%
df_test['brand'] = label_encoder.fit_transform(df_test['brand'])
df_test['fuel_type'] = label_encoder.fit_transform(df_test['fuel_type'])
df_test['ext_col'] = label_encoder.fit_transform(df_test['ext_col'])
df_test['int_col'] = label_encoder.fit_transform(df_test['int_col'])
df_test['model'] = label_encoder.fit_transform(df_test['model'])

# %%
df_train['transmission'].value_counts()
# Out:
# transmission
# A/T                                                   16757
# 8-Speed A/T                                            7287
# Transmission w/Dual Shift Mode                         6454
# 6-Speed A/T                                            5944
# 6-Speed M/T                                            3618
# 7-Speed A/T                                            3415
# 10-Speed A/T                                           2187
# 8-Speed Automatic                                      1189
# 5-Speed A/T                                            1185
# 9-Speed A/T                                            1073
# 4-Speed A/T                                             764
# 5-Speed M/T                                             718
# CVT Transmission                                        692
# 10-Speed Automatic                                      642
# 6-Speed Automatic                                       516
# Automatic                                               441
# M/T                                                     359
# 9-Speed Automatic                                       344
# 7-Speed Automatic with Auto-Shift                       110
# 7-Speed M/T                                             104
# Automatic CVT                                            95
# 1-Speed A/T                                              60
# 8-Speed Automatic with Auto-Shift                        55
# Transmission Overdrive Switch                            54
# 7-Speed Automatic                                        41
# 6-Speed Manual                                           34
# 5-Speed Automatic                                        24
# 7-Speed Manual                                           22
# 6-Speed Automatic with Auto-Shift                        17
# 8-Speed Manual                                            9
# 4-Speed Automatic                                         8
# 7-Speed                                                   7
# –                                                         7
# 7-Speed DCT Automatic                                     6
# 1-Speed Automatic                                         6
# 6-Speed Electronically Controlled Automatic with O        6
# 10-Speed Automatic with Overdrive                         5
# 2-Speed A/T                                               5
# 6-Speed                                                   3
# 9-Speed Automatic with Auto-Shift                         2
# SCHEDULED FOR OR IN PRODUCTION                            2
# 6 Speed Mt                                                2
# CVT-F                                                     1
# F                                                         1
# Variable                                                  1
# 6 Speed At/Mt                                             1
# Name: count, dtype: int64

# %%
def classify_transmission(trans):
    if 'A/T' in trans or 'Automatic' in trans:
        return 'Automatic'
    elif 'M/T' in trans or 'Manual' in trans or 'Mt' in trans:
        return 'Manual'
    elif 'CVT' in trans:
        return 'CVT'
    else:
        return 'Dual Shift Mode'

# %%
df_train['trans'] = df_train['transmission'].apply(classify_transmission)
df_test['trans'] = df_test['transmission'].apply(classify_transmission)

# %%
import re
def extract_info(spec):
    hp_match = re.search(r'(\d+\.?\d*)HP', spec)
    hp = hp_match.group(1) if hp_match else None

    displacement_match = re.search(r'(\d+\.\d+)L', spec)
    displacement = displacement_match.group(1) if displacement_match else None
    
    return pd.Series([hp, displacement])

# %%
df_train[['HP', 'cyl_capacity']] = df_train['engine'].apply(extract_info)
df_test[['HP', 'cyl_capacity']] = df_test['engine'].apply(extract_info)

# %%
def extract_engine_type(engine):
    if 'V6' in engine:
        return 'V6'
    elif 'V8' in engine:
        return 'V8'
    elif 'Straight 6' in engine:
        return 'Straight 6'
    else:
        return 'Other'

# %%
df_train['engine_type'] = df_train['engine'].apply(extract_engine_type)
df_test['engine_type'] = df_test['engine'].apply(extract_engine_type)

# %%
df_train['accident'] = df_train['accident'].map({'None reported':0, 'At least 1 accident or damage reported':1})
df_test['accident'] = df_test['accident'].map({'None reported':0, 'At least 1 accident or damage reported':1})

# %%
df_train.drop('clean_title', axis=1, inplace=True)

# %%
df_test.drop('clean_title', axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    brand  model  model_year  milage  fuel_type  \
# 0     14    644        2018   74349          2
# 1      4     49        2007   80000          2
# 2     21   1771        2009   91491          2
# 3      4   1748        2022    2437          3
# 4     40    693        2001  111000          2
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission  ext_col  int_col  accident  price  \
# 0                    10-Speed A/T       26       57         0  11000
# 1                     6-Speed M/T       17        9         0   8250
# 2                     6-Speed A/T      181        6         0  15000
# 3  Transmission w/Dual Shift Mode      100       24         0  63500
# 4                             A/T      249        9         0   7850
#
#              trans     HP cyl_capacity engine_type
# 0        Automatic  375.0          3.5          V6
# 1           Manual  300.0          3.0  Straight 6
# 2        Automatic  300.0          4.2       Other
# 3  Dual Shift Mode  335.0          3.0  Straight 6
# 4        Automatic  200.0          3.8          V6

# %%
def classify_transmission2(trans):
    parts = trans.split('-') if '-' in trans else trans.split(' ')
    speed = parts[0] if 'Speed' in trans else None
    return speed

# %%
df_train['speed'] = df_train['transmission'].apply(classify_transmission2)
df_test['speed'] = df_test['transmission'].apply(classify_transmission2)

# %%
df_train.shape
# Out:
# (54273, 16)

# %%
def replace_nan_with_average(df):
    df['speed'] = pd.to_numeric(df['speed'], errors='coerce')
    average_speeds = df.groupby('trans')['speed'].mean()
    for category, avg_speed in average_speeds.items():
        df.loc[df['speed'].isna() & (df['trans'] == category), 'speed'] = avg_speed
    return df

# Test the function
df_train = replace_nan_with_average(df_train)
df_test = replace_nan_with_average(df_test)

# %%
# Convert the column to numeric, ignoring non-numeric values
df_train['speed'] = pd.to_numeric(df_train['speed'], errors='coerce')
df_test['speed'] = pd.to_numeric(df_test['speed'], errors='coerce')
# Calculate the mean of the column
mean_value = df_train['speed'].mean()
mean_value_test = df_test['speed'].mean()
# Replace missing values with the mean
df_train['speed'].fillna(mean_value, inplace=True)
df_test['speed'].fillna(mean_value_test, inplace=True)
# Convert the column to integers
df_train['speed'] = df_train['speed'].astype('int64')
df_test['speed'] = df_test['speed'].astype('int64')

# %%
df_train.drop(['engine', 'transmission'], axis=1, inplace=True)
df_test.drop(['engine', 'transmission'], axis=1, inplace=True)

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# HP              4057
# cyl_capacity     606
# brand              0
# model              0
# model_year         0
# milage             0
# fuel_type          0
# ext_col            0
# int_col            0
# accident           0
# price              0
# trans              0
# engine_type        0
# speed              0
# dtype: int64

# %%
mode_per_group_train = df_train.groupby('trans')['cyl_capacity'].apply(lambda x: x.mode()[0])
mode_per_group_train
# Out:
# trans
# Automatic          3.0
# CVT                3.5
# Dual Shift Mode    3.0
# Manual             2.0
# Name: cyl_capacity, dtype: object

# %%
mode_per_group_test = df_train.groupby('trans')['cyl_capacity'].apply(lambda x: x.mode()[0])
mode_per_group_test
# Out:
# trans
# Automatic          3.0
# CVT                3.5
# Dual Shift Mode    3.0
# Manual             2.0
# Name: cyl_capacity, dtype: object

# %%
df_train['cyl_capacity'] = df_train.apply(lambda row: mode_per_group_train[row['trans']]
                              if pd.isna(row['cyl_capacity']) else row['cyl_capacity'],
                              axis=1)
df_test['cyl_capacity'] = df_test.apply(lambda row: mode_per_group_test[row['trans']]
                              if pd.isna(row['cyl_capacity']) else row['cyl_capacity'],
                              axis=1)

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# HP              4057
# brand              0
# model              0
# model_year         0
# milage             0
# fuel_type          0
# ext_col            0
# int_col            0
# accident           0
# price              0
# trans              0
# cyl_capacity       0
# engine_type        0
# speed              0
# dtype: int64

# %%
mode_per_group_train = df_train.groupby('trans')['HP'].apply(lambda x: x.mode()[0])
mode_per_group_train
# Out:
# trans
# Automatic          300.0
# CVT                188.0
# Dual Shift Mode    300.0
# Manual             455.0
# Name: HP, dtype: object

# %%
mode_per_group_test = df_test.groupby('trans')['HP'].apply(lambda x: x.mode()[0])
mode_per_group_test
# Out:
# trans
# Automatic          300.0
# CVT                188.0
# Dual Shift Mode    300.0
# Manual             455.0
# Name: HP, dtype: object

# %%
df_train['HP'] = df_train.apply(lambda row: mode_per_group_train[row['trans']]
                    if pd.isna(row['HP']) else row['HP'],
                    axis=1)
df_test['HP'] = df_test.apply(lambda row: mode_per_group_test[row['trans']]
                    if pd.isna(row['HP']) else row['HP'],
                    axis=1)

# %%
df_train.isnull().sum().sort_values(ascending=False)
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# ext_col         0
# int_col         0
# accident        0
# price           0
# trans           0
# HP              0
# cyl_capacity    0
# engine_type     0
# speed           0
# dtype: int64

# %%
df_train.head()
# Out:
#    brand  model  model_year  milage  fuel_type  ext_col  int_col  accident  \
# 0     14    644        2018   74349          2       26       57         0
# 1      4     49        2007   80000          2       17        9         0
# 2     21   1771        2009   91491          2      181        6         0
# 3      4   1748        2022    2437          3      100       24         0
# 4     40    693        2001  111000          2      249        9         0
#
#    price            trans     HP cyl_capacity engine_type  speed
# 0  11000        Automatic  375.0          3.5          V6     10
# 1   8250           Manual  300.0          3.0  Straight 6      6
# 2  15000        Automatic  300.0          4.2       Other      6
# 3  63500  Dual Shift Mode  335.0          3.0  Straight 6      6
# 4   7850        Automatic  200.0          3.8          V6      7

# %%
df_train['trans'] = df_train['trans'].map({'Automatic':0, 'Manual':1, 'Dual Shift Mode':3, 'CVT':4})
df_test['trans'] = df_test['trans'].map({'Automatic':0, 'Manual':1, 'Dual Shift Mode':3, 'CVT':4})

# %%
df_train['engine_type'].unique()
# Out:
# array(['V6', 'Straight 6', 'Other', 'V8'], dtype=object)

# %%
df_train['engine_type'] = df_train['engine_type'].map({'V6':0, 'Straight 6':1, 'Other':3, 'V8':4})
df_test['engine_type'] = df_test['engine_type'].map({'V6':0, 'Straight 6':1, 'Other':3, 'V8':4})

# %%
df_train.head()
# Out:
#    brand  model  model_year  milage  fuel_type  ext_col  int_col  accident  \
# 0     14    644        2018   74349          2       26       57         0
# 1      4     49        2007   80000          2       17        9         0
# 2     21   1771        2009   91491          2      181        6         0
# 3      4   1748        2022    2437          3      100       24         0
# 4     40    693        2001  111000          2      249        9         0
#
#    price  trans     HP cyl_capacity  engine_type  speed
# 0  11000      0  375.0          3.5            0     10
# 1   8250      1  300.0          3.0            1      6
# 2  15000      0  300.0          4.2            3      6
# 3  63500      3  335.0          3.0            1      6
# 4   7850      0  200.0          3.8            0      7

# %%
df_train.isnull().sum()
# Out:
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# ext_col         0
# int_col         0
# accident        0
# price           0
# trans           0
# HP              0
# cyl_capacity    0
# engine_type     0
# speed           0
# dtype: int64

# %%
df_train.dtypes
# Out:
# brand            int64
# model            int64
# model_year       int64
# milage           int64
# fuel_type        int64
# ext_col          int64
# int_col          int64
# accident         int64
# price            int64
# trans            int64
# HP              object
# cyl_capacity    object
# engine_type      int64
# speed            int64
# dtype: object

# %%
df_train['cyl_capacity'] = df_train['cyl_capacity'].astype('float64')
df_train['HP'] = df_train['HP'].astype('float64')

# %%
df_train.dtypes
# Out:
# brand             int64
# model             int64
# model_year        int64
# milage            int64
# fuel_type         int64
# ext_col           int64
# int_col           int64
# accident          int64
# price             int64
# trans             int64
# HP              float64
# cyl_capacity    float64
# engine_type       int64
# speed             int64
# dtype: object

# %%
df_test.head()
# Out:
#    brand  model  model_year  milage  fuel_type  ext_col  int_col  accident  \
# 0     34    528        2014   73000          2      220        8         0
# 1     26   1246        2015  128032          2      187       10         0
# 2     34    317        2015   51983          2       26      107         0
# 3     25   1318        2018   29500          2      220      107         1
# 4      4   1710        2020   90000          2      220       10         1
#
#    trans     HP cyl_capacity  engine_type  speed
# 0      0  302.0          3.5            0      7
# 1      0  275.0          3.5            0      8
# 2      0  241.0          2.0            3      7
# 3      3  518.0          5.0            3      6
# 4      0  335.0          3.0            1      8

# %%
df_test.dtypes
# Out:
# brand            int32
# model            int32
# model_year       int64
# milage           int64
# fuel_type        int32
# ext_col          int32
# int_col          int32
# accident         int64
# trans            int64
# HP              object
# cyl_capacity    object
# engine_type      int64
# speed            int64
# dtype: object

# %%
df_test['cyl_capacity'] = df_test['cyl_capacity'].astype('float64')
df_test['HP'] = df_test['HP'].astype('float64')

# %%
df_test.describe()
# Out:
#               brand         model    model_year         milage     fuel_type  \
# count  36183.000000  36183.000000  36183.000000   36183.000000  36183.000000
# mean      20.582318    877.038526   2015.063953   72479.266755      1.995799
# std       14.296537    531.404726      5.589336   50714.968252      0.487344
# min        0.000000      0.000000   1974.000000     100.000000      0.000000
# 25%        9.000000    445.000000   2012.000000   31681.000000      2.000000
# 50%       17.000000    816.000000   2016.000000   65680.000000      2.000000
# 75%       34.000000   1350.000000   2019.000000  102000.000000      2.000000
# max       52.000000   1790.000000   2024.000000  405000.000000      6.000000
#
#             ext_col       int_col      accident         trans            HP  \
# count  36183.000000  36183.000000  36183.000000  36183.000000  36183.000000
# mean     109.705884     23.433436      0.264903      0.503717    329.965011
# std       84.676938     26.990487      0.441288      1.061708    105.721904
# min        0.000000      0.000000      0.000000      0.000000     70.000000
# 25%       17.000000     10.000000      0.000000      0.000000    261.000000
# 50%       88.000000     10.000000      0.000000      0.000000    302.000000
# 75%      220.000000     23.000000      1.000000      0.000000    395.000000
# max      229.000000    110.000000      1.000000      4.000000    835.000000
#
#        cyl_capacity   engine_type         speed
# count  36183.000000  36183.000000  36183.000000
# mean       3.717073      1.882099      6.908189
# std        1.333220      1.407131      1.178842
# min        0.650000      0.000000      1.000000
# 25%        3.000000      0.000000      6.000000
# 50%        3.500000      3.000000      7.000000
# 75%        4.600000      3.000000      7.000000
# max        8.400000      4.000000     10.000000

# %%
df_test.shape
# Out:
# (36183, 13)

# %%
corr_matrix = df_train.corr()

plt.figure(figsize=(10, 8))  
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, annot_kws={"size": 10}, fmt=".2f")  
plt.xticks(rotation=45, ha='right', fontsize=12)  
plt.yticks(fontsize=12)  
plt.title('Correlation Matrix', fontsize=16)
plt.tight_layout()  
plt.show()

# %%
df_train.drop(['fuel_type'], axis=1, inplace=True)
df_test.drop(['fuel_type'], axis=1, inplace=True)

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_train['milage'] = scaler.fit_transform(df_train[['milage']])
df_test['milage'] = scaler.fit_transform(df_test[['milage']])

# %%
num_columns = df_train.shape[1]
num_rows = (num_columns + 2) // 3  # 3 columns per row, add 2 to round up

# Plot boxplots for all numerical features
plt.figure(figsize=(15, num_rows * 5))
for i, column in enumerate(df_train.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.boxplot(y=df_train[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, num_rows * 5))
for i, column in enumerate(df_train.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.histplot(df_train[column], kde=True)  # Use histplot for distribution plots
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %%
epsilon = 1e-8  # Small constant to avoid zero values, if necessary

df_train['price'] = np.log(df_train['price'])
df_train['int_col'] = np.log(df_train['int_col']+ epsilon)
df_test['int_col'] = np.log(df_test['int_col']+ epsilon)

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
from scipy.stats import zscore
def remove_outliers_zscore(df, column_name, threshold=3):
    z_scores = zscore(df[column_name])
    mask = (z_scores < threshold) & (z_scores > -threshold)
    return df[mask]
df_train = remove_outliers_zscore(df_train, 'HP')
df_train = remove_outliers_zscore(df_train, 'price')

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
df_train = remove_outliers(df_train, 'milage')

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
plt.figure(figsize=(15, num_rows * 5))
for i, column in enumerate(df_train.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.histplot(df_train[column], kde=True)  # Use histplot for distribution plots
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %%
num_columns = df_train.shape[1]
num_rows = (num_columns + 2) // 3  # 3 columns per row, add 2 to round up

# Plot boxplots for all numerical features
plt.figure(figsize=(15, num_rows * 5))
for i, column in enumerate(df_train.columns, 1):
    plt.subplot(num_rows, 3, i)
    sns.boxplot(y=df_train[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %%
df_train.head()
# Out:
#    brand  model  model_year    milage  ext_col   int_col  accident      price  \
# 0     14    644        2018  0.031759       26  4.043051         0   9.305651
# 1      4     49        2007  0.143728       17  2.197225         0   9.017968
# 2     21   1771        2009  0.371412      181  1.791759         0   9.615805
# 3      4   1748        2022 -1.393115      100  3.178054         0  11.058795
# 4     40    693        2001  0.757966      249  2.197225         0   8.968269
#
#    trans     HP  cyl_capacity  engine_type  speed
# 0      0  375.0           3.5            0     10
# 1      1  300.0           3.0            1      6
# 2      0  300.0           4.2            3      6
# 3      3  335.0           3.0            1      6
# 4      0  200.0           3.8            0      7

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/a2/48/d5da8591891327b0faf08179d420fba3893c6134bdd449497c5329e4cb01/xgboost-2.1.0-py3-none-win_amd64.whl.metadata
#   Downloading xgboost-2.1.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\hp\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Downloading xgboost-2.1.0-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 39.3 kB/s eta 0:52:55
#    ---------------------------------------- 0.0/124.9 MB 39.3 kB/s eta 0:52:55
#    ---------------------------------------- 0.0/124.9 MB 39.3 kB/s eta 0:52:55
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 77.7 kB/s eta 0:26:46
#    ---------------------------------------- 0.1/124.9 MB 40.0 kB/s eta 0:51:59
#    ---------------------------------------- 0.1/124.9 MB 40.0 kB/s eta 0:51:59
#    ---------------------------------------- 0.1/124.9 MB 40.0 kB/s eta 0:51:59
#    ---------------------------------------- 0.1/124.9 MB 40.0 kB/s eta 0:51:59
kB/s eta 0:00:01
#    -------------------------------------  124.5/124.9 MB 853.5 kB/s eta 0:00:01
#    -------------------------------------  124.5/124.9 MB 852.5 kB/s eta 0:00:01
#    -------------------------------------  124.5/124.9 MB 852.5 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.6/124.9 MB 845.9 kB/s eta 0:00:01
#    -------------------------------------  124.7/124.9 MB 809.3 kB/s eta 0:00:01
#    -------------------------------------  124.7/124.9 MB 809.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------  124.9/124.9 MB 815.3 kB/s eta 0:00:01
#    -------------------------------------- 124.9/124.9 MB 784.9 kB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.0

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Define models
model_dict = {
    'Linear Regression': LinearRegression(),
    'Decision Tree Regression': DecisionTreeRegressor(),
    'Random Forest Regression': RandomForestRegressor(),
    'Support Vector Machine Regression': SVR(),
    'XGBoost Regression': xgb.XGBRegressor(),
    'GB Regressor': GradientBoostingRegressor(),
    'Ada Boost Regression': AdaBoostRegressor()
}

# %%
X = df_train.drop(['price'], axis=1)
y = df_train['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((42412, 12), (10604, 12), (42412,), (10604,))

# %%
df_test.shape
# Out:
# (36183, 12)

# %%
print(np.any(np.isnan(X_train)))
print(np.any(np.isinf(X_train)))
# Out:
# False
# False

# %%
# Create pipelines
pipelines = {name: model for name, model in model_dict.items()}

# Dictionary to store RMSE results
rmse_results = {}

# Train models and calculate RMSE
for name, pipeline in pipelines.items():
    pipeline.fit(X_train, y_train)
    predictions = pipeline.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_results[name] = rmse

# Display RMSE results
rmse_results_sorted = dict(sorted(rmse_results.items(), key=lambda item: item[1]))
print(rmse_results_sorted)
# Out:
# {'XGBoost Regression': 0.45845688068880225, 'GB Regressor': 0.46329427035756177, 'Random Forest Regression': 0.4676819377918151, 'Linear Regression': 0.4897076687375804, 'Ada Boost Regression': 0.5161567191596438, 'Support Vector Machine Regression': 0.5857215650195068, 'Decision Tree Regression': 0.6447159225645628}

# %%
xgb_model = xgb.XGBRegressor()
linear_model = LinearRegression()
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Predict using the test set
y_pred = xgb_model.predict(X_test)

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse}")

# Calculate R-squared (R²)
r2 = r2_score(y_test, y_pred)
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 0.21018271145090667
# R-squared (R²): 0.6629571262653374

# %%
y_pred = xgb_model.predict(df_test)

# %%
y_pred.shape
# Out:
# (36183,)

# %%
y_pred = np.exp(y_pred)

# %%
y_pred.shape
# Out:
# (36183,)

# %%
# Create a DataFrame for submission
sub = pd.DataFrame({
    'id': test_id,  # Assuming 'Id' is the identifier column in your test data
    'price': y_pred
})

# %%
sub.to_csv('sub.csv', index=False)

# %%
sub.head(20)
# Out:
#        id         price
# 0   54273  26433.169922
# 1   54274  16428.232422
# 2   54275  31653.019531
# 3   54276  48358.160156
# 4   54277  28709.794922
# 5   54278  69486.492188
# 6   54279  40476.648438
# 7   54280  32341.535156
# 8   54281  12755.188477
# 9   54282  57999.476562
# 10  54283  32851.281250
# 11  54284  13316.998047
# 12  54285  41820.937500
# 13  54286  33183.566406
# 14  54287  38165.250000
# 15  54288  66941.039062
# 16  54289  74876.023438
# 17  54290  31345.382812
# 18  54291  13694.802734
# 19  54292  74124.820312
